# %% [markdown]
# Code to demonstrate tetrad_plus capabilities.

# %%
from tetrad_plus import TetradPlus
from dgraph_flex import DgraphFlex
import semopy
import pprint as pp

# %%
# create  an instance o MyTetradSearch
tp = TetradPlus()

# set the data and knowledge files
data_file = 'tetrad_plus/data/boston_data_raw.csv'
knowledge_file = 'tetrad_plus/data/boston_prior.txt'
# Out:
# Attempting to start JVM with classpath: /Users/kolim/Projects/tetrad_plus/tetrad_plus/jars/tetrad-gui-7.6.3-launch.jar

# %%
# read in the data
df = tp.read_csv(data_file)
df
# Out:
#      alcohol_bev    TIB       TST  PANAS_PA  PANAS_NA  worry_scale  PHQ9
# 0            1.0   9.00  7.333333      44.0      13.0          8.0   0.0
# 1            0.0  10.25  8.750000      40.0      12.0         14.0   0.0
# 2            1.0   8.50  7.166667      39.0      12.0         15.0   0.0
# 3            1.0   8.75  8.083333      39.0      12.0         12.0   0.0
# 4            1.0   8.25  6.666667      38.0      13.0         15.0   0.0
# ..           ...    ...       ...       ...       ...          ...   ...
# 636          4.0   8.75  7.916667      29.0      12.0         17.0   3.0
# 637          4.0   8.50  7.666667      31.0      12.0         17.0   4.0
# 638          3.0   8.50  7.583333      33.0      13.0         17.0   3.0
# 639          3.0   9.00  8.166667      31.0      12.0         19.0   2.0
# 640          4.0   8.25  7.416667      31.0      13.0         17.0   1.0
#
# [641 rows x 7 columns]

# %%
# add the lags, with a suffix of '_lag'
df_lag = tp.add_lag_columns(df, lag_stub='_lag')
df_lag
# Out:
#      alcohol_bev    TIB       TST  PANAS_PA  PANAS_NA  worry_scale  PHQ9  \
# 0            0.0  10.25  8.750000      40.0      12.0         14.0   0.0
# 1            1.0   8.50  7.166667      39.0      12.0         15.0   0.0
# 2            1.0   8.75  8.083333      39.0      12.0         12.0   0.0
# 3            1.0   8.25  6.666667      38.0      13.0         15.0   0.0
# 4            0.0   8.25  7.416667      37.0      12.0         16.0   0.0
# ..           ...    ...       ...       ...       ...          ...   ...
# 635          4.0   8.75  7.916667      29.0      12.0         17.0   3.0
# 636          4.0   8.50  7.666667      31.0      12.0         17.0   4.0
# 637          3.0   8.50  7.583333      33.0      13.0         17.0   3.0
# 638          3.0   9.00  8.166667      31.0      12.0         19.0   2.0
# 639          4.0   8.25  7.416667      31.0      13.0         17.0   1.0
#
#      alcohol_bev_lag  TIB_lag   TST_lag  PANAS_PA_lag  PANAS_NA_lag  \
# 0                1.0     9.00  7.333333          44.0          13.0
# 1                0.0    10.25  8.750000          40.0          12.0
# 2                1.0     8.50  7.166667          39.0          12.0
# 3                1.0     8.75  8.083333          39.0          12.0
# 4                1.0     8.25  6.666667          38.0          13.0
# ..               ...      ...       ...           ...           ...
# 635              6.0     7.00  6.166667          31.0          15.0
# 636              4.0     8.75  7.916667          29.0          12.0
# 637              4.0     8.50  7.666667          31.0          12.0
# 638              3.0     8.50  7.583333          33.0          13.0
# 639              3.0     9.00  8.166667          31.0          12.0
#
#      worry_scale_lag  PHQ9_lag
# 0                8.0       0.0
# 1               14.0       0.0
# 2               15.0       0.0
# 3               12.0       0.0
# 4               15.0       0.0
# ..               ...       ...
# 635             18.0       3.0
# 636             17.0       3.0
# 637             17.0       4.0
# 638             17.0       3.0
# 639             19.0       2.0
#
# [640 rows x 14 columns]

# %%
# standardize the data
df_lag_std = tp.standardize_df_cols(df_lag)
df_lag_std
# Out:
#      alcohol_bev       TIB       TST  PANAS_PA  PANAS_NA  worry_scale  \
# 0      -0.720086  0.945596  0.714807  1.403653 -0.442144    -1.025409
# 1      -0.048041 -0.349371 -0.463029  1.300809 -0.442144    -0.866815
# 2      -0.048041 -0.164376  0.218876  1.300809 -0.442144    -1.342597
# 3      -0.048041 -0.534367 -0.834977  1.197966 -0.237832    -0.866815
# 4      -0.720086 -0.534367 -0.277055  1.095122 -0.442144    -0.708221
# ..           ...       ...       ...       ...       ...          ...
# 635     1.968095 -0.164376  0.094893  0.272375 -0.442144    -0.549627
# 636     1.968095 -0.349371 -0.091081  0.478062 -0.442144    -0.549627
# 637     1.296050 -0.349371 -0.153072  0.683748 -0.237832    -0.549627
# 638     1.296050  0.020619  0.280867  0.478062 -0.442144    -0.232439
# 639     1.968095 -0.534367 -0.277055  0.478062 -0.237832    -0.549627
#
#          PHQ9  alcohol_bev_lag   TIB_lag   TST_lag  PANAS_PA_lag  \
# 0   -0.961531        -0.045027  0.019757 -0.338939      1.808615
# 1   -0.961531        -0.719118  0.944940  0.714883      1.398222
# 2   -0.961531        -0.045027 -0.350317 -0.462918      1.295624
# 3   -0.961531        -0.045027 -0.165280  0.218966      1.295624
# 4   -0.961531        -0.045027 -0.535353 -0.834856      1.193025
# ..        ...              ...       ...       ...           ...
# 635  0.053947         3.325425 -1.460537 -1.206793      0.474838
# 636  0.392440         1.977244 -0.165280  0.094987      0.269641
# 637  0.053947         1.977244 -0.350317 -0.090981      0.474838
# 638 -0.284546         1.303154 -0.350317 -0.152971      0.680034
# 639 -0.623038         1.303154  0.019757  0.280956      0.474838
#
#      PANAS_NA_lag  worry_scale_lag  PHQ9_lag
# 0       -0.237832        -1.969207 -0.960600
# 1       -0.442144        -1.020311 -0.960600
# 2       -0.442144        -0.862161 -0.960600
# 3       -0.442144        -1.336610 -0.960600
# 4       -0.237832        -0.862161 -0.960600
# ..            ...              ...       ...
# 635      0.170792        -0.387713  0.054453
# 636     -0.442144        -0.545863  0.054453
# 637     -0.442144        -0.545863  0.392805
# 638     -0.237832        -0.545863  0.054453
# 639     -0.442144        -0.229564 -0.283898
#
# [640 rows x 14 columns]

# %%
# read the prior file for testing
prior_lines = tp.read_prior_file(knowledge_file)
# extract knowledge from the prior lines
knowledge = tp.extract_knowledge(prior_lines)

knowledge
# Out:
# {'addtemporal': {0: ['alcohol_bev_lag',
#    'TIB_lag',
#    'TST_lag',
#    'PANAS_PA_lag',
#    'PANAS_NA_lag',
#    'worry_scale_lag',
#    'PHQ9_lag'],
#   1: ['alcohol_bev',
#    'TIB',
#    'TST',
#    'PANAS_PA',
#    'PANAS_NA',
#    'worry_scale',
#    'PHQ9']}}

# %%
# Run the search
searchResult = tp.run_model_search( df_lag_std, 
                                    model='gfci', 
                                    knowledge=knowledge, 
                                    score={'sem_bic': {'penalty_discount': 1.0}},
                                    test={'fisher_z': {'alpha': .01}})

searchResult
# Out:
# {'edges': ['PANAS_PA <-> PHQ9',
#   'PANAS_NA <-> PANAS_NA_lag',
#   'worry_scale_lag --> alcohol_bev_lag',
#   'PANAS_NA_lag --> worry_scale_lag',
#   'worry_scale_lag --> TST_lag',
#   'worry_scale --> TST',
#   'worry_scale_lag --> worry_scale',
#   'TST_lag --> TST',
#   'PHQ9 --> PANAS_NA',
#   'alcohol_bev_lag --> alcohol_bev',
#   'worry_scale --> PANAS_PA',
#   'TIB <-> TST',
#   'PHQ9_lag --> PHQ9',
#   'PANAS_PA_lag --> PHQ9_lag',
#   'TIB_lag o-> TST_lag',
#   'PANAS_NA --> worry_scale',
#   'PANAS_PA_lag --> PANAS_PA',
#   'PHQ9 <-> PANAS_NA_lag',
#   'PHQ9_lag <-> PANAS_NA_lag',
#   'worry_scale_lag --> PANAS_PA_lag',
#   'TIB_lag o-> TIB',
#   'TIB --> PANAS_NA'],
#  'raw_output': 'Graph Nodes:
#  alcohol_bev;TIB;TST;PANAS_PA;PANAS_NA;worry_scale;PHQ9;alcohol_bev_lag;TIB_lag;TST_lag;PANAS_PA_lag;PANAS_NA_lag;worry_scale_lag;PHQ9_lag
#
#  Graph Edges:
#  1. PANAS_NA <-> PANAS_NA_lag
#  2. PANAS_NA --> worry_scale
#  3. PANAS_NA_lag --> worry_scale_lag
#  4. PANAS_PA <-> PHQ9
#  5. PANAS_PA_lag --> PANAS_PA
#  6. PANAS_PA_lag --> PHQ9_lag
#  7. PHQ9 --> PANAS_NA
#  8. PHQ9 <-> PANAS_NA_lag
#  9. PHQ9_lag <-> PANAS_NA_lag
#  10. PHQ9_lag --> PHQ9
#  11. TIB --> PANAS_NA
#  12. TIB <-> TST
#  13. TIB_lag o-> TIB
#  14. TIB_lag o-> TST_lag
#  15. TST_lag --> TST
#  16. alcohol_bev_lag --> alcohol_bev
#  17. worry_scale --> PANAS_PA
#  18. worry_scale --> TST
#  19. worry_scale_lag --> PANAS_PA_lag
#  20. worry_scale_lag --> TST_lag
#  21. worry_scale_lag --> alcohol_bev_lag
#  22. worry_scale_lag --> worry_scale
#
#  Graph Attributes:
#  Score: 3172.813979
#
#  Graph Node Attributes:
#  Score: [alcohol_bev: 172.87676691624958;TIB: 80.91216858716189;TST: 337.33205502616806;PANAS_PA: 546.8971740314278;PANAS_NA: 459.73787073092376;worry_scale: 423.83299935376795;PHQ9: 442.93375670363486;alcohol_bev_lag: 3.6692592377492437;TIB_lag: 1.69796379805764;TST_lag: 294.5736492612772;PANAS_PA_lag: 74.63108260165806;PANAS_NA_lag: -0.5003910323781992;worry_scale_lag: 59.45634441122257;PHQ9_lag: 274.7632796903881]
#  '}

# %%
# show the raw graph
obj = DgraphFlex()
# create a list of the edges
edges = list(searchResult['edges'])
# add the edges to the graph object
obj.add_edges(edges)
# show the graph
obj.show_graph()

# %%
# run the sem

# convert the edges from searchResult to lavaan format
lavaan_model = tp.edges_to_lavaan(edges)
lavaan_model
# Out:
# 'alcohol_bev_lag ~ worry_scale_lag\nworry_scale_lag ~ PANAS_NA_lag\nTST_lag ~ worry_scale_lag\nTST ~ worry_scale\nworry_scale ~ worry_scale_lag\nTST ~ TST_lag\nPANAS_NA ~ PHQ9\nalcohol_bev ~ alcohol_bev_lag\nPANAS_PA ~ worry_scale\nPHQ9 ~ PHQ9_lag\nPHQ9_lag ~ PANAS_PA_lag\nTST_lag ~ TIB_lag\nworry_scale ~ PANAS_NA\nPANAS_PA ~ PANAS_PA_lag\nPANAS_PA_lag ~ worry_scale_lag\nTIB ~ TIB_lag\nPANAS_NA ~ TIB\n'

# %%
# run semopy with the lavaan model and the data
sem_results = tp.run_semopy(lavaan_model, df_lag_std)
# the main output we are interested in is the parameter estimates
sem_results['estimates']
# Out:
#                lval  op             rval  Estimate  Std. Err    z-value  \
# 0   alcohol_bev_lag   ~  worry_scale_lag  0.151137  0.039076   3.867740
# 1   worry_scale_lag   ~     PANAS_NA_lag -0.423252  0.035812 -11.818585
# 2           TST_lag   ~  worry_scale_lag  0.127595  0.024717   5.162206
# 3           TST_lag   ~          TIB_lag  0.772753  0.024717  31.264564
# 4       worry_scale   ~  worry_scale_lag  0.813082  0.020299  40.055897
# 5       worry_scale   ~         PANAS_NA -0.105783  0.020301  -5.210741
# 6          PANAS_NA   ~             PHQ9  0.735885  0.026273  28.008687
# 7          PANAS_NA   ~              TIB -0.126198  0.026271  -4.803788
# 8              PHQ9   ~         PHQ9_lag  0.860557  0.020126  42.759366
# 9          PHQ9_lag   ~     PANAS_PA_lag -0.478610  0.034707 -13.790130
# 10     PANAS_PA_lag   ~  worry_scale_lag  0.367615  0.036761  10.000129
# 11              TIB   ~          TIB_lag  0.482106  0.034631  13.921280
# 12              TST   ~      worry_scale  0.077131  0.037235   2.071444
# 13              TST   ~          TST_lag  0.402202  0.036082  11.146785
# 14      alcohol_bev   ~  alcohol_bev_lag  0.651113  0.029993  21.709019
# 15         PANAS_PA   ~      worry_scale  0.068142  0.019073   3.572712
# 16         PANAS_PA   ~     PANAS_PA_lag  0.870260  0.018612  46.758569
# 17         PANAS_NA  ~~         PANAS_NA  0.441672  0.024690  17.888544
# 18     PANAS_PA_lag  ~~     PANAS_PA_lag  0.864848  0.048346  17.888544
# 19             PHQ9  ~~             PHQ9  0.259217  0.014491  17.888544
# 20         PHQ9_lag  ~~         PHQ9_lag  0.770905  0.043095  17.888544
# 21              TIB  ~~              TIB  0.767549  0.042907  17.888544
# 22          TST_lag  ~~          TST_lag  0.389804  0.021791  17.888544
# 23  alcohol_bev_lag  ~~  alcohol_bev_lag  0.977215  0.054628  17.888544
# 24      worry_scale  ~~      worry_scale  0.260220  0.014547  17.888544
# 25  worry_scale_lag  ~~  worry_scale_lag  0.820820  0.045885  17.888544
# 26         PANAS_PA  ~~         PANAS_PA  0.196171  0.010966  17.888544
# 27              TST  ~~              TST  0.826487  0.046202  17.888544
# 28      alcohol_bev  ~~      alcohol_bev  0.575754  0.032186  17.888544
#
#          p-value
# 0   1.098487e-04
# 1   0.000000e+00
# 2   2.440560e-07
# 3   0.000000e+00
# 4   0.000000e+00
# 5   1.880884e-07
# 6   0.000000e+00
# 7   1.556915e-06
# 8   0.000000e+00
# 9   0.000000e+00
# 10  0.000000e+00
# 11  0.000000e+00
# 12  3.831728e-02
# 13  0.000000e+00
# 14  0.000000e+00
# 15  3.533027e-04
# 16  0.000000e+00
# 17  0.000000e+00
# 18  0.000000e+00
# 19  0.000000e+00
# 20  0.000000e+00
# 21  0.000000e+00
# 22  0.000000e+00
# 23  0.000000e+00
# 24  0.000000e+00
# 25  0.000000e+00
# 26  0.000000e+00
# 27  0.000000e+00
# 28  0.000000e+00

# %%
# save the graph generated by semopy
# plot into png
png_path = 'boston_data.png'
g = semopy.semplot(sem_results['model'], png_path,  plot_covs = True)

# %%
# add the sem results to our graph object

tp.add_sem_results_to_graph(obj, sem_results['estimates'])
# save the graph to a png file
obj.save_graph(plot_format='png', plot_name='boston_graph_single_sem')

# show the graph
obj.show_graph()

# %% [markdown]
# In the next section, we perform the stability analysis.
#
# We do 100 runs with a subsample 90% without substitution.
#
# We keep edges that are present at least 75%.
#
# stable_edges contains the edges that were found 75% of the time.

# %%
# run the stability search
stable_edges, sorted_edges, sorted_edges_raw, run_results = tp.run_stability_search(
                                        df, 
                                        model='gfci',
                                        knowledge=knowledge,
                                        score={'sem_bic': {'penalty_discount': 1.0}},
                                        test={'fisher_z': {'alpha': .01}},
                                        runs=100,
                                        min_fraction=0.75,
                                        subsample_fraction=0.9,
                                        save_file='stability_search_results.json',)

stable_edges
# Out:
# Running stability search with 100 runs:   0%|          | 0/100 [00:00<?, ?run/s]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[13], line 2
#       1 # run the stability search
# ----> 2 stable_edges, sorted_edges, sorted_edges_raw, run_results = tp.run_stability_search(
#       3                                         df,
#       4                                         model='gfci',
#       5                                         knowledge=knowledge,
#       6                                         score={'sem_bic': {'penalty_discount': 1.0}},
#       7                                         test={'fisher_z': {'alpha': .01}},
#       8                                         runs=100,
#       9                                         min_fraction=0.75,
#      10                                         subsample_fraction=0.9,
#      11                                         save_file='stability_search_results.json',)
#      13 stable_edges
#
# File ~/Projects/tetrad_plus/tetrad_plus/tetrad_plus.py:808, in TetradPlus.run_stability_search(self, full_df, model, knowledge, score, test, runs, min_fraction, subsample_fraction, random_state, lag_flag, save_file)
#     802 searchResult = self.run_model_search(df, model=model,
#     803                                     knowledge=knowledge,
#     804                                     score=score,
#     805                                     test=test,
#     806                                     verbose=True)
#     807 # get the edges
# --> 808 edges = searchResult['setEdges']
#     809 # loop over the edges
#     810 for edge in edges:
#
# KeyError: 'setEdges'

# %%
# lets show the sorted edges
sorted_edges

# %%
# show the run_results
run_results

# %% [markdown]
# Let's create a graph of these edges

# %%
obj = DgraphFlex()
obj.add_edges(stable_edges)
# show the graph
obj.show_graph()

# %% [markdown]
# Now that we have the edges, lets run the sem and show the causal graph.

# %%
lavaan_model = ts.edges_to_lavaan(stable_edges)

# run semopy, using the lagged and standardized data
sem_results = ts.run_semopy(lavaan_model, df_lag_std)
# add the semopy results to the graph object
ts.add_sem_results_to_graph(obj, sem_results['estimates'])
# save the graph to a png file
obj.save_graph(plot_format='png', plot_name='boston_graph_stable_sem')
# show the graph
obj.show_graph()

# %% [markdown]
# The prior graph was using a threshold of 0.75 for an edge to be included in the graph.  Let's change this to .9.

# %%
# Let's get a new set of edges based on the min_fractio of 0.9
selected_edges = ts.select_edges(sorted_edges, min_fraction=0.8)

selected_edges

# %%
# run the sem and create a new graph
obj = DgraphFlex()
obj.add_edges(selected_edges)

# run the sem
lavaan_model = ts.edges_to_lavaan(selected_edges)
sem_results = ts.run_semopy(lavaan_model, df_lag_std)
# add the semopy results to the graph object
ts.add_sem_results_to_graph(obj, sem_results['estimates'])
# save the graph to a png file
obj.show_graph()
